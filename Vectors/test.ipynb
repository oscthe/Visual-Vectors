# %%
from Vectors import Vector

# %%
vec1 = Vector(2,3)
vec2 = Vector(3,3)
vec3 = Vector(-3,-3)

# %%
vec1.plot()

# %%
vec5 = Vector(4,4)
vec6 = Vector(-10,4)

vec5.addplot(vec6)

# %%
vec5.length()
# Out:
# 5.656854249492381
